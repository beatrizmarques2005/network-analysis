# %% [markdown]
# <font size=10>**EXPLORATION**</font> <a class="anchor" id='title'></a>
#
# **Bachelor's in Data Science - NOVA IMS (25/26)**
#
# **Project**: [*Portal BASE*](https://www.base.gov.pt/Base4/pt/pesquisa/?type=contratos&texto=&adjudicante=&adjudicataria=&tipo=2&tipocontrato=0&cpv=&aqinfo=&desdeprazoexecucao=&ateprazoexecucao=&sel_price=price_11&desdeprecocontrato=&ateprecocontrato=&desdeprecoefectivo=&ateprecoefectivo=&sel_date=date_11&desdedatacontrato=2023-01-01&atedatacontrato=2026-03-31&desdedatapublicacao=&atedatapublicacao=&desdedatafecho=&atedatafecho=&pais=0&distrito=0&concelho=0)
#
# **Filters Applied**:
# - Tipo de procedimento: Concurso público
# - Data do contrato desde: 2023-01-01
# - Data do contrato até: 2026-03-31
#
# **Group B**
# - Beatriz Marques 20231605
# - Maria Inês Santos 20231630
# - Luís Soeiro 20211536
# - Rodrigo Silva 20231602

# %% [markdown]
# <font color='#BFD72' size=6>**TABLE OF CONTENTS**</font> <a class="anchor" id='toc'></a>
# - [1. Imports](#1)
# - [2. Data Integration](#2)
# - [3. Data Exploration](#3)

# %% [markdown]
# # <font color='#BFD72F' size=6>**1. Imports**</font> <a class="anchor" id="1"></a>
#
# [Back to TOC](#toc)

# %%
import pandas as pd

# %% [markdown]
# # <font color='#BFD72F' size=6>**2. Data Integration**</font> <a class="anchor" id="2"></a>
#
# [Back to TOC](#toc)

# %%
df = pd.read_csv(
	r"../data/data.csv",
	sep=None,
	engine="python", 
	on_bad_lines="skip"
)
df.head()
# Out:
#                                  ﻿Objeto do Contrato Tipo de Procedimento  \
# 0  Remodelação da praia das Palmeiras, manutenção...     Concurso público
# 1  Empreitada de Reabilitação de Fogos Devolutos ...     Concurso público
# 2  Concurso Público com publicidade no Jornal Ofi...     Concurso público
# 3  Serviços análise de dados para manutenção evol...     Concurso público
# 4  Serviços de técnico de suporte IT, para o supo...     Concurso público
#
#              Tipo(s) de Contrato         CPV  CPV Tipo   \
# 0  Empreitadas de obras públicas  45259000-7  Principal
# 1  Empreitadas de obras públicas  45453100-8  Principal
# 2       Aquisição de bens móveis  48200000-0  Principal
# 3          Aquisição de serviços  72500000-0  Principal
# 4          Aquisição de serviços  72500000-0  Principal
#
#                                       CPV Designação     CPV Valor  \
# 0              Reparação e manutenção de instalações   138440.2 €
# 1                               Obras de recuperação   275000.0 €
# 2  Pacote de software para ligações em rede, Inte...  338257.16 €
# 3            Serviços relacionados com a informática   283966.4 €
# 4            Serviços relacionados com a informática  489828.77 €
#
#                           Entidade(s) Adjudicante(s)  \
# 0                Município de Santa Cruz (511244681)
# 1  IHM - Investimentos Habitacionais da Madeira, ...
# 2  Instituto para os Comportamentos Aditivos e as...
# 3  Serviços Partilhados do Ministério da Saúde, E...
# 4  Serviços Partilhados do Ministério da Saúde, E...
#
#                         Entidade(s) Adjudicatária(s) Preço Contratual  ...  \
# 0  SCTM - Sociedade Construções Técnicas da Madei...     138.440,20 €  ...
# 1  Sales, Faria & Andrade- Sociedade de Construçõ...     275.000,00 €  ...
# 2              Claranet II Solutions, SA (510728189)     338.257,16 €  ...
# 3               Integer Consulting, S.A. (507969332)     283.966,40 €  ...
# 4  IDW - CONSULTORIA EM SERVIÇOS DE INFORMAÇÃO, L...     489.828,77 €  ...
#
#   Descrição do Acordo Quadro Procedimento Centralizado  \
# 0             Não aplicável.                     False
# 1             Não aplicável.                     False
# 2             Não aplicável.                      True
# 3             Não aplicável.                     False
# 4             Não aplicável.                     False
#
#                   Ligação para Peças do Procedimento  \
# 0  https://www.acingov.pt/acingovprod/2/zonaPubli...
# 1  https://www.acingov.pt/acingovprod/2/zonaPubli...
# 2  https://community.vortal.biz/Public/public-ten...
# 3  https://community.vortal.biz/Public/public-ten...
# 4  https://community.vortal.biz/Public/public-ten...
#
#   Lista de Fornecedores (cocontratantes)  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Aquisição ao Abrigo de Acordo Quadro de outro Estado-membro da UE  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Medidas especiais                                             Regime  \
# 0                NaN  Código dos Contratos Públicos (DL 111-B/2017) ...
# 1                NaN  Código dos Contratos Públicos (DL 111-B/2017) ...
# 2                NaN  Código dos Contratos Públicos (DL111-B/2017) e...
# 3                NaN  Código dos Contratos Públicos (DL111-B/2017) e...
# 4                NaN  Código dos Contratos Públicos (DL111-B/2017) e...
#
#    Critérios Materiais    CCP  groupMembers
# 0                False  False           NaN
# 1                False  False           NaN
# 2                False  False           NaN
# 3                False  False           NaN
# 4                False  False           NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# # <font color='#BFD72F' size=6>**3. Data Exploration**</font> <a class="anchor" id="3"></a>
#
# [Back to TOC](#toc)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 32 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   ﻿Objeto do Contrato                                                250 non-null    str
#  1   Tipo de Procedimento                                               250 non-null    str
#  2   Tipo(s) de Contrato                                                250 non-null    str
#  3   CPV                                                                250 non-null    str
#  4   CPV Tipo                                                           250 non-null    str
#  5   CPV Designação                                                     250 non-null    str
#  6   CPV Valor                                                          250 non-null    str
#  7   Entidade(s) Adjudicante(s)                                         250 non-null    str
#  8   Entidade(s) Adjudicatária(s)                                       250 non-null    str
#  9   Preço Contratual                                                   250 non-null    str
#  10  Data de Publicação                                                 250 non-null    str
#  11  Data de Celebração do Contrato                                     250 non-null    str
#  12  Prazo de Execução                                                  250 non-null    str
#  13  Local de Execução                                                  250 non-null    str
#  14  Fundamentação                                                      250 non-null    str
#  15  Causa de Extinção do Contrato                                      0 non-null      float64
#  16  Data de Fecho do Contrato                                          0 non-null      float64
#  17  Preço Total Efetivo                                                0 non-null      float64
#  18  Causas das Alterações ao Prazo                                     0 non-null      float64
#  19  Causas das Alterações ao Preço                                     0 non-null      float64
#  20  Estado                                                             0 non-null      float64
#  21  N.º registo do Acordo Quadro                                       250 non-null    str
#  22  Descrição do Acordo Quadro                                         250 non-null    str
#  23  Procedimento Centralizado                                          250 non-null    bool
#  24  Ligação para Peças do Procedimento                                 249 non-null    str
#  25  Lista de Fornecedores (cocontratantes)                             250 non-null    bool
#  26  Aquisição ao Abrigo de Acordo Quadro de outro Estado-membro da UE  0 non-null      float64
#  27  Medidas especiais                                                  0 non-null      float64
#  28  Regime                                                             250 non-null    str
#  29  Critérios Materiais                                                250 non-null    bool
#  30  CCP                                                                250 non-null    bool
#  31  groupMembers                                                       0 non-null      float64
# dtypes: bool(4), float64(9), str(19)
# memory usage: 55.8 KB

# %%
df.columns
# Out:
# Index(['﻿Objeto do Contrato', 'Tipo de Procedimento', 'Tipo(s) de Contrato',
#        'CPV', 'CPV Tipo ', 'CPV Designação', 'CPV Valor',
#        'Entidade(s) Adjudicante(s)', 'Entidade(s) Adjudicatária(s)',
#        'Preço Contratual', 'Data de Publicação',
#        'Data de Celebração do Contrato', 'Prazo de Execução',
#        'Local de Execução', 'Fundamentação', 'Causa de Extinção do Contrato',
#        'Data de Fecho do Contrato', 'Preço Total Efetivo',
#        'Causas das Alterações ao Prazo', 'Causas das Alterações ao Preço',
#        'Estado', 'N.º registo do Acordo Quadro', 'Descrição do Acordo Quadro',
#        'Procedimento Centralizado', 'Ligação para Peças do Procedimento',
#        'Lista de Fornecedores (cocontratantes)',
#        'Aquisição ao Abrigo de Acordo Quadro de outro Estado-membro da UE',
#        'Medidas especiais', 'Regime', 'Critérios Materiais', 'CCP',
#        'groupMembers'],
#       dtype='str')

# %%
df['Entidade(s) Adjudicante(s)'].nunique()
# Out:
# 131

# %%
df['Entidade(s) Adjudicatária(s)'].nunique()
# Out:
# 209

# %%
df["Data de Celebração do Contrato"]
# Out:
# 0      27-03-2026
# 1      02-03-2026
# 2      25-03-2026
# 3      30-03-2026
# 4      30-03-2026
#           ...
# 245    30-03-2026
# 246    27-03-2026
# 247    31-03-2026
# 248    30-03-2026
# 249    26-03-2026
# Name: Data de Celebração do Contrato, Length: 250, dtype: str
